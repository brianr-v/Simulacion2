# %% [markdown]
# # Distancia Manhattan
#
# ## Caminta en un plano
#
# Iniciamos suponiendo que una persona que se puede mover al azar en cuatro direcciones (N, S, E, O). Despues de varios pasos, la persona se encontrara en una posición final $(x_f,y_f)$, entonces queremos determinar
#
# $\begin{equation}d_m=|x_f - x_i| + |y_f-y_i|\end{equation}$
#
# Como ejercicio, necesitamos determinar, dado N pasos encontrar a una longuitud no más de 4 del 50%.

# %% [markdown]
# # Simulación
#
# ## Importación de las librerías

# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# ## Definimos funciones
#
# * Función movimiento():
# Donde definimos las variables "x" y "y", lo que hace es generar un numero aleatorio que serán los pasos que dara dependiendo (Norte, Sur, Este, Oeste). Reegresa "x" y "y".
#
# * Función probabilidad(n, k):
# Donde calculo la distancia Manhattan con la formula:
# $\begin{equation}d_m=|x_f - x_i| + |y_f-y_i|\end{equation}$
# Regresa la media de las distancias.

# %%
def movimiento(n):
    y = 0
    x = 0
    for i in range(n):
        aleatorio = random.randint(0,3)
        if aleatorio == 0:
            y += 1
        elif aleatorio == 1:
            y -= 1
        elif aleatorio == 2:
            x += 1
        else:
            x -= 1
    return x, y

def probabilidad(n,k):
    contador = 0

    for i in range(n):
        xi = 0
        yi = 0
        sim = movimiento(k)
        xf = sim[0]
        yf = sim[1]
        
        if (abs(xi - xf) + abs(yi-yf)) <= 4:
            contador += 1
    return contador/n

# %% [markdown]
# ## Llamamos a las funciones

# %%
lineas = 100
n = 20000

lista_probabilidad = []

for i in range(1,lineas+1):
    
    proba = probabilidad(n,i)
    lista_probabilidad.append(proba)
    print("Probabilidad: ",proba, " con ", i, " caminos")

numero_mas_cercano = min(lista_probabilidad, key=lambda x: abs(x - 0.5))
print("\n El número mas cercano a 0.5 es, ",numero_mas_cercano, " que es el camino ", lista_probabilidad.index(numero_mas_cercano) + 1)
# Out:
# Probabilidad:  1.0  con  1  caminos
# Probabilidad:  1.0  con  2  caminos
# Probabilidad:  1.0  con  3  caminos
# Probabilidad:  1.0  con  4  caminos
# Probabilidad:  0.8745  con  5  caminos
# Probabilidad:  0.9414  con  6  caminos
# Probabilidad:  0.7626  con  7  caminos
# Probabilidad:  0.8625  con  8  caminos
# Probabilidad:  0.6677  con  9  caminos
# Probabilidad:  0.79315  con  10  caminos
# Probabilidad:  0.59845  con  11  caminos
# Probabilidad:  0.72655  con  12  caminos
# Probabilidad:  0.53675  con  13  caminos
# Probabilidad:  0.66495  con  14  caminos
# Probabilidad:  0.4816  con  15  caminos
# Probabilidad:  0.6181  con  16  caminos
# Probabilidad:  0.4499  con  17  caminos
# Probabilidad:  0.5796  con  18  caminos
# Probabilidad:  0.4045  con  19  caminos
# Probabilidad:  0.54565  con  20  caminos
# Probabilidad:  0.3751  con  21  caminos
# Probabilidad:  0.5097  con  22  caminos
# Probabilidad:  0.36  con  23  caminos
# Probabilidad:  0.47515  con  24  caminos
# Probabilidad:  0.33655  con  25  caminos
# Probabilidad:  0.4532  con  26  caminos
# Probabilidad:  0.31605  con  27  caminos
# Probabilidad:  0.4285  con  28  caminos
# Probabilidad:  0.29635  con  29  caminos
# Probabilidad:  0.4108  con  30  caminos
# Probabilidad:  0.2717  con  31  caminos
# Probabilidad:  0.3929  con  32  caminos
# Probabilidad:  0.26055  con  33  caminos
# Probabilidad:  0.3714  con  34  caminos
# Probabilidad:  0.25065  con  35  caminos
# Probabilidad:  0.35625  con  36  caminos
# Probabilidad:  0.24285  con  37  caminos
# Probabilidad:  0.3403  con  38  caminos
# Probabilidad:  0.23055  con  39  caminos
# Probabilidad:  0.323  con  40  caminos
# Probabilidad:  0.21675  con  41  caminos
# Probabilidad:  0.3146  con  42  caminos
# Probabilidad:  0.2131  con  43  caminos
# Probabilidad:  0.30265  con  44  caminos
# Probabilidad:  0.20255  con  45  caminos
# Probabilidad:  0.2946  con  46  caminos
# Probabilidad:  0.1916  con  47  caminos
# Probabilidad:  0.2759  con  48  caminos
# Probabilidad:  0.185  con  49  caminos
# Probabilidad:  0.27475  con  50  caminos
# Probabilidad:  0.1812  con  51  caminos
# Probabilidad:  0.25085  con  52  caminos
# Probabilidad:  0.17605  con  53  caminos
# Probabilidad:  0.2607  con  54  caminos
# Probabilidad:  0.16595  con  55  caminos
# Probabilidad:  0.2432  con  56  caminos
# Probabilidad:  0.161  con  57  caminos
# Probabilidad:  0.23725  con  58  caminos
# Probabilidad:  0.15795  con  59  caminos
# Probabilidad:  0.22415  con  60  caminos
# Probabilidad:  0.1531  con  61  caminos
# Probabilidad:  0.22575  con  62  caminos
# Probabilidad:  0.14825  con  63  caminos
# Probabilidad:  0.21765  con  64  caminos
# Probabilidad:  0.1447  con  65  caminos
# Probabilidad:  0.2119  con  66  caminos
# Probabilidad:  0.1447  con  67  caminos
# Probabilidad:  0.20325  con  68  caminos
# Probabilidad:  0.1378  con  69  caminos
# Probabilidad:  0.2019  con  70  caminos
# Probabilidad:  0.13245  con  71  caminos
# Probabilidad:  0.1974  con  72  caminos
# Probabilidad:  0.131  con  73  caminos
# Probabilidad:  0.19195  con  74  caminos
# Probabilidad:  0.12525  con  75  caminos
# Probabilidad:  0.19095  con  76  caminos
# Probabilidad:  0.1244  con  77  caminos
# Probabilidad:  0.1837  con  78  caminos
# Probabilidad:  0.12155  con  79  caminos
# Probabilidad:  0.17975  con  80  caminos
# Probabilidad:  0.1202  con  81  caminos
# Probabilidad:  0.17735  con  82  caminos
# Probabilidad:  0.115  con  83  caminos
# Probabilidad:  0.1717  con  84  caminos
# Probabilidad:  0.1107  con  85  caminos
# Probabilidad:  0.1699  con  86  caminos
# Probabilidad:  0.10675  con  87  caminos
# Probabilidad:  0.1643  con  88  caminos
# Probabilidad:  0.1047  con  89  caminos
# Probabilidad:  0.1587  con  90  caminos
# Probabilidad:  0.1038  con  91  caminos
# Probabilidad:  0.15735  con  92  caminos
# Probabilidad:  0.10485  con  93  caminos
# Probabilidad:  0.1587  con  94  caminos
# Probabilidad:  0.1048  con  95  caminos
# Probabilidad:  0.154  con  96  caminos
# Probabilidad:  0.1002  con  97  caminos
# Probabilidad:  0.1484  con  98  caminos
# Probabilidad:  0.09705  con  99  caminos
# Probabilidad:  0.14605  con  100  caminos
#
#  El número mas cercano a 0.5 es,  0.5097  que es el camino  22
